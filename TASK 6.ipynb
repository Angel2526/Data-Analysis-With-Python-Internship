# %% [markdown]
# # ADVANCED - DATA ANALYSIS TECHNIQUES

# %% [markdown]
# # Description

# %% [markdown]
# Apply advanced statistical and analytical methods to solve complex problems.

# %% [markdown]
# 1. Implement time series analysis for forecasting trends and seasonality.
# 2. Perform sentiment analysis or text mining on unstructured data.
# 3. Explore clustering or classification techniques for segmentation and pattern recognition.

# %%
# Importing nessecary libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Loading the dataset

data = pd.read_csv("C:/Users/ANGEL SARA PETER/Downloads/disney_plus_titles.csv")

# %%
data
# Out:
#      show_id     type                           title  \
# 0         s1    Movie                   A Spark Story
# 1         s2    Movie                  Spooky Buddies
# 2         s3    Movie          The Fault in Our Stars
# 3         s4  TV Show                 Dog: Impossible
# 4         s5  TV Show  Spidey And His Amazing Friends
# ...      ...      ...                             ...
# 1363   s1364    Movie          The Sword in the Stone
# 1364   s1365    Movie                 Those Calloways
# 1365   s1366  TV Show            Disney Kirby Buckets
# 1366   s1367  TV Show                  Disney Mech-X4
# 1367   s1368  TV Show              Imagination Movers
#
#                         director  \
# 0     Jason Sterman, Leanne Dare
# 1                   Robert Vince
# 2                     Josh Boone
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1363         Wolfgang Reitherman
# 1364                Norman Tokar
# ...

# %%
data.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %%
data.tail()
# Out:
#      show_id     type                   title             director  \
# 1363   s1364    Movie  The Sword in the Stone  Wolfgang Reitherman
# 1364   s1365    Movie         Those Calloways         Norman Tokar
# 1365   s1366  TV Show    Disney Kirby Buckets                  NaN
# 1366   s1367  TV Show          Disney Mech-X4                  NaN
# 1367   s1368  TV Show      Imagination Movers                  NaN
#
#                                                    cast        country  \
# 1363  Sebastian Cabot, Karl Swenson, Rickie Sorensen...  United States
# 1364  Brian Keith, Vera Miles, Brandon de Wilde, Wal...  United States
# 1365  Jacob Bertrand, Mekai Curtis, Cade Sutton, Oli...  United States
# 1366  Nathaniel Potvin, Raymond Cham, Kamran Lucas, ...         Canada
# 1367  Rich Collins, Dave Poche, Scott Durbin, Scott ...  United States
#
#            date_added  release_year rating   duration  \
# 1363  October 1, 2019          1963      G     80 min
# ...

# %%
data.describe()
# Out:
#        release_year
# count   1368.000000
# mean    2002.348684
# std       22.127559
# min     1928.000000
# 25%     1998.000000
# 50%     2011.000000
# 75%     2018.000000
# max     2021.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1368 non-null   object
#  1   type          1368 non-null   object
#  2   title         1368 non-null   object
#  3   director      928 non-null    object
#  4   cast          1194 non-null   object
#  5   country       1193 non-null   object
#  6   date_added    1365 non-null   object
#  7   release_year  1368 non-null   int64
#  8   rating        1366 non-null   object
#  9   duration      1368 non-null   object
#  10  listed_in     1368 non-null   object
#  11  description   1368 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 128.4+ KB

# %%
import missingno as msno

# missingno is a Python library that provides a convenient way to visualize and analyze missing data in datasets.

# %%
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
#Removes duplicate rows from the DataFrame, modifying it in place to ensure that only unique rows are retained. 

data.drop_duplicates(inplace=True)

# %%
data
# Out:
#      show_id     type                           title  \
# 0         s1    Movie                   A Spark Story
# 1         s2    Movie                  Spooky Buddies
# 2         s3    Movie          The Fault in Our Stars
# 3         s4  TV Show                 Dog: Impossible
# 4         s5  TV Show  Spidey And His Amazing Friends
# ...      ...      ...                             ...
# 1363   s1364    Movie          The Sword in the Stone
# 1364   s1365    Movie                 Those Calloways
# 1365   s1366  TV Show            Disney Kirby Buckets
# 1366   s1367  TV Show                  Disney Mech-X4
# 1367   s1368  TV Show              Imagination Movers
#
#                         director  \
# 0     Jason Sterman, Leanne Dare
# 1                   Robert Vince
# 2                     Josh Boone
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1363         Wolfgang Reitherman
# 1364                Norman Tokar
# ...

# %%
data.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        440
# cast            174
# country         175
# date_added        3
# release_year      0
# rating            2
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
# Drops the columns 'director', 'cast', 'country', and 'description' from the DataFrame

data.drop(['director','cast','country','description'],axis=1,inplace=True)

# %%
data
# Out:
#      show_id     type                           title          date_added  \
# 0         s1    Movie                   A Spark Story  September 24, 2021
# 1         s2    Movie                  Spooky Buddies  September 24, 2021
# 2         s3    Movie          The Fault in Our Stars  September 24, 2021
# 3         s4  TV Show                 Dog: Impossible  September 22, 2021
# 4         s5  TV Show  Spidey And His Amazing Friends  September 22, 2021
# ...      ...      ...                             ...                 ...
# 1363   s1364    Movie          The Sword in the Stone     October 1, 2019
# 1364   s1365    Movie                 Those Calloways     October 1, 2019
# 1365   s1366  TV Show            Disney Kirby Buckets                 NaN
# 1366   s1367  TV Show                  Disney Mech-X4                 NaN
# 1367   s1368  TV Show              Imagination Movers                 NaN
#
#       release_year rating   duration  \
# 0             2021  TV-PG     88 min
# ...

# %%
# Fills missing values in the 'rating' column with the mode, drops any remaining rows with missing data, and converts the 'date_added' column to datetime format.data['rating'].fillna(data['rating'].mode)

data.dropna(inplace=True)
data['date_added']=pd.to_datetime(data['date_added'])

# %%
data
# Out:
#      show_id     type                           title date_added  \
# 0         s1    Movie                   A Spark Story 2021-09-24
# 1         s2    Movie                  Spooky Buddies 2021-09-24
# 2         s3    Movie          The Fault in Our Stars 2021-09-24
# 3         s4  TV Show                 Dog: Impossible 2021-09-22
# 4         s5  TV Show  Spidey And His Amazing Friends 2021-09-22
# ...      ...      ...                             ...        ...
# 1360   s1361  TV Show                       Smart Guy 2019-10-01
# 1361   s1362    Movie        The Cat from Outer Space 2019-10-01
# 1362   s1363    Movie       The Great Mouse Detective 2019-10-01
# 1363   s1364    Movie          The Sword in the Stone 2019-10-01
# 1364   s1365    Movie                 Those Calloways 2019-10-01
#
#       release_year rating   duration                             listed_in
# 0             2021  TV-PG     88 min                           Documentary
# ...

# %%
#Extracts the month, day, and year from the 'date_added' column, creating new columns 'month', 'day', and 'added_year' in the DataFrame to store these values. 

data['month']=data['date_added'].dt.month
data['day']=data['date_added'].dt.day
data['added_year']=data['date_added'].dt.year

# %%
data
# Out:
#      show_id     type                           title date_added  \
# 0         s1    Movie                   A Spark Story 2021-09-24
# 1         s2    Movie                  Spooky Buddies 2021-09-24
# 2         s3    Movie          The Fault in Our Stars 2021-09-24
# 3         s4  TV Show                 Dog: Impossible 2021-09-22
# 4         s5  TV Show  Spidey And His Amazing Friends 2021-09-22
# ...      ...      ...                             ...        ...
# 1360   s1361  TV Show                       Smart Guy 2019-10-01
# 1361   s1362    Movie        The Cat from Outer Space 2019-10-01
# 1362   s1363    Movie       The Great Mouse Detective 2019-10-01
# 1363   s1364    Movie          The Sword in the Stone 2019-10-01
# 1364   s1365    Movie                 Those Calloways 2019-10-01
#
#       release_year rating   duration                             listed_in  \
# 0             2021  TV-PG     88 min                           Documentary
# ...

# %%
questions =["1) What are different types of genre and which is highly watched?",
    "2) How does the number of titles added vary by month?",
    "3) What is the distribution of ratings?",
    "4) Which year has the highest movies/TV Shows realesed?",
    "5) What is the relationship between the date a title was added and its release year?",
    "6) How does the number of movies added each year vary by release year?"]

# %% [markdown]
# ## 1. What are different types of genre and which is highly watched?

# %%
data['type'].value_counts()
# Out:
# Movie      990
# TV Show    373
# Name: type, dtype: int64

# %%
#Creates a pie chart showing the distribution of 'Movie' and 'TV Show' types with percentage labels and a title.

plt.pie(data['type'].value_counts(),labels=['Movie','TV Show'],autopct='%2f')
plt.title('Different types of Genre')
plt.tight_layout()

# %% [markdown]
# ## 2. How does the number of titles added vary by month?

# %%
#Creates a bar plot to visualize the number of titles added each month, with a title and labeled axes  

sns.countplot(x='month', data=data)
plt.title('Number of Titles Added by Month')
plt.xlabel('Month')
plt.ylabel('Number of Titles')
plt.tight_layout()

# %%
data['month'].value_counts(ascending=True)
# Out:
# 3      22
# 10     34
# 2      44
# 9      52
# 8      52
# 12     52
# 6      54
# 1      61
# 5      64
# 7      85
# 4      86
# 11    757
# Name: month, dtype: int64

# %% [markdown]
# ## 3. What is the distribution of ratings?

# %%
#Creates a horizontal bar plot to show the distribution of ratings, with a title and labeled axes 

sns.countplot(y='rating', data=data)
plt.title('Distribution of Ratings by Type')
plt.xlabel('Type')
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
data['rating'].value_counts(ascending=True)
# Out:
# TV-Y7-FV     12
# TV-Y         47
# PG-13        60
# TV-14        72
# TV-Y7       128
# PG          227
# G           235
# TV-PG       275
# TV-G        307
# Name: rating, dtype: int64

# %% [markdown]
# ## 4. Which year has the highest movies/TV Shows realesed?

# %%
#Plots a bar chart of the top 10 release years by number of titles, distinguishing between Movies and TV Shows.

type_year_df = data.groupby(['release_year', 'type']).size().unstack().fillna(0)
type_year_df['Total'] = type_year_df.sum(axis=1)
top_10_years = type_year_df.sort_values('Total', ascending=False).head(10).drop(columns=['Total'])
top_10_years.plot(kind='bar', color=['yellow', 'red'])
plt.title('Top 10 Release Years by Number of Titles (Movies vs. TV Shows)')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.legend(title='Type')
plt.tight_layout()

# %% [markdown]
# ## 5. What is the relationship between the date a title was added and its release year?

# %%
#Creates a scatter plot of release year versus rating, with a title and labeled axes.

sns.scatterplot(x='release_year', y='rating', data=data)
plt.title('Release Year vs Rating')
plt.xlabel('Release Year')
plt.ylabel('Rating')
plt.tight_layout()

# %% [markdown]
# ## 6. How does the number of movies added each year vary by release year?

# %%
#Plots a bar chart of the number of movies added each year with years on the x-axis and counts on the y-axis.

movies_df = data[data['type'] == 'Movie']
movies_per_year = movies_df['release_year'].value_counts().sort_index()
plt.figure(figsize=(16,5))
movies_per_year.plot(kind='bar', color='red')
plt.title('Number of Movies Added Each Year by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Number of Movies Added')
plt.xticks(rotation=90);
